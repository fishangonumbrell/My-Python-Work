# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
x=np.linspace(0,2*(np.pi),100)

# %%
y=np.sin(x)+np.cos(x)

# %%
plt.plot(x,y)

# %%
np.pi
# Out:
# 3.141592653589793
